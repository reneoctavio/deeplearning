# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import sklearn.metrics as sklm
from sklearn.preprocessing import label_binarize

# %pylab inline

# Set the right path to your model definition file, pretrained model weights,
# and the image you would like to classify.
MODEL_PATH    = '/Users/reneoctavio/Documents/leafsnap/bvlc_googlenet/'
DATASET_PATH  = '/Users/reneoctavio/Documents/leafsnap/'
SNAPSHOT_PATH = '/Volumes/Windows/Snapshots/leafsnap/bvlc_googlenet/'

CAT_FILE      = DATASET_PATH  + 'species.txt'
PREDICTIONS   = MODEL_PATH + 'prediction-top-5-test-50000.npy'
TRUE_VALUES   = MODEL_PATH + 'true-label-test-50000.npy'
PREDICTION_SC = MODEL_PATH + 'prediction-score-test-50000.npy'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Read Species
sp_file = open(CAT_FILE, 'r')
dicCat = {}
listCat = []
for line in sp_file:
    ln = line.split()
    num = int(ln[len(ln) - 1])
    name = ' '.join(ln[0:(len(ln)-1)])
    dicCat[num] = name
for key, name in dicCat.items():
    listCat.append(name)
    
# Read True Values and Predictions
predictions = np.load(PREDICTIONS).astype(int)
true_values = np.load(TRUE_VALUES).astype(int)

print(predictions.shape)
print(true_values.shape)
# Out:
# (3240, 5)
# (3240,)

# %%
# Plot Conf Mat function
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='None', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(listCat))
    plt.xticks(tick_marks, listCat, rotation=90)
    plt.yticks(tick_marks, listCat)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# # Use of complete test set
# Calculation of precision and accuracy of the test set

# %%
print(sklm.precision_recall_fscore_support(true_values, predictions[:,0], average='weighted'))
print(sklm.accuracy_score(true_values, predictions[:,0]))
print(sklm.classification_report(true_values, predictions[:,0], target_names=listCat))
# Out:
# (0.970796728494567, 0.96944444444444444, 0.9693307769315731, None)
# 0.969444444444
#                               precision    recall  f1-score   support
#
#               Abies concolor       0.93      1.00      0.96        26
#           Abies nordmanniana       1.00      0.94      0.97        17
#               Acer campestre       1.00      1.00      1.00        16
#                 Acer ginnala       1.00      0.94      0.97        16
#                 Acer griseum       1.00      1.00      1.00        13
#                 Acer negundo       1.00      1.00      1.00        24
#                Acer palmatum       1.00      1.00      1.00        22
#           Acer pensylvanicum       1.00      1.00      1.00        16
#             Acer platanoides       1.00      0.93      0.96        14
#          Acer pseudoplatanus       1.00      1.00      1.00        14
#                  Acer rubrum       1.00      1.00      1.00        31
#             Acer saccharinum       1.00      1.00      1.00        20
#               Acer saccharum       1.00      1.00      1.00        19
#               Aesculus flava       1.00      1.00      1.00        14
#              Aesculus glabra       1.00      1.00      1.00        18
#       Aesculus hippocastamon       1.00      1.00      1.00        15
#                Aesculus pavi       1.00      1.00      1.00        23
#          Ailanthus altissima       1.00      1.00      1.00        12
#          Albizia julibrissin       1.00      1.00      1.00        16
#          Amelanchier arborea       0.86      0.86      0.86        14
#       Amelanchier canadensis       0.93      0.88      0.90        16
#           Amelanchier laevis       1.00      1.00      1.00        16
#              Asimina triloba       1.00      1.00      1.00        26
#      Liquidambar styraciflua       1.00      1.00      1.00        17
#      Liriodendron tulipifera       1.00      1.00      1.00        24
#             Maclura pomifera       1.00      1.00      1.00        46
#           Magnolia acuminata       1.00      1.00      1.00        16
#            Magnolia denudata       1.00      1.00      1.00        18
#         Magnolia grandiflora       1.00      1.00      1.00        14
#         Magnolia macrophylla       1.00      1.00      1.00        16
#         Magnolia soulangiana       0.75      1.00      0.86         6
#            Magnolia stellata       0.80      0.89      0.84        18
#           Magnolia tripetala       0.86      0.75      0.80        16
#          Magnolia virginiana       0.95      1.00      0.97        19
#           Malus angustifolia       0.90      1.00      0.95         9
#                Malus baccata       1.00      1.00      1.00        16
#              Malus coronaria       1.00      0.94      0.97        16
#             Malus floribunda       1.00      1.00      1.00        16
#             Malus hupehensis       1.00      1.00      1.00        16
#                 Malus pumila       1.00      1.00      1.00        18
# Metasequoia glyptostroboides       1.00      0.94      0.97        18
#                   Morus alba       0.94      1.00      0.97        15
#                  Morus rubra       1.00      1.00      1.00        15
#              Nyssa sylvatica       0.94      0.89      0.91        18
#            Ostrya virginiana       0.96      1.00      0.98        22
#          Oxydendrum arboreum       1.00      0.94      0.97        18
#          Paulownia tomentosa       1.00      1.00      1.00        15
#       Phellodendron amurense       1.00      1.00      1.00        16
#                  Picea abies       1.00      1.00      1.00        18
#             Picea orientalis       1.00      0.94      0.97        18
#                Picea pungens       0.94      0.89      0.91        18
#               Pinus bungeana       1.00      0.95      0.97        19
#                 Pinus cembra       1.00      0.95      0.97        19
#             Pinus densiflora       1.00      1.00      1.00        18
#               Pinus echinata       0.89      1.00      0.94        17
#               Pinus flexilis       0.89      0.94      0.91        17
#             Pinus koraiensis       0.94      1.00      0.97        17
#                  Pinus nigra       0.94      0.94      0.94        17
#             Pinus parviflora       1.00      0.89      0.94        18
#                 Pinus peucea       0.94      0.94      0.94        16
#                Pinus pungens       1.00      1.00      1.00        17
#               Pinus resinosa       1.00      1.00      1.00        17
#                 Pinus rigida       1.00      1.00      1.00        18
#                Pinus strobus       0.93      1.00      0.97        14
#             Pinus sylvestris       1.00      0.94      0.97        16
#                  Pinus taeda       1.00      0.94      0.97        17
#             Pinus thunbergii       0.93      1.00      0.96        13
#             Pinus virginiana       0.67      0.71      0.69        17
#            Pinus wallichiana       1.00      1.00      1.00        16
#          Platanus acerifolia       0.93      1.00      0.97        14
#        Platanus occidentalis       1.00      1.00      1.00        20
#            Populus deltoides       1.00      1.00      1.00        17
#        Populus grandidentata       1.00      1.00      1.00        17
#          Populus tremuloides       1.00      0.94      0.97        17
#          Prunus pensylvanica       1.00      0.93      0.97        15
#             Prunus sargentii       0.73      0.73      0.73        30
#              Prunus serotina       1.00      1.00      1.00        16
#             Prunus serrulata       1.00      1.00      1.00        14
#           Prunus subhirtella       0.82      0.50      0.62        18
#            Prunus virginiana       0.62      0.74      0.68        31
#             Prunus yedoensis       1.00      1.00      1.00        15
#         Pseudolarix amabilis       0.94      1.00      0.97        16
#            Ptelea trifoliata       1.00      1.00      1.00        27
#             Pyrus calleryana       1.00      1.00      1.00        18
#           Quercus acutissima       1.00      1.00      1.00        18
#                 Quercus alba       1.00      1.00      1.00        18
#              Quercus bicolor       1.00      1.00      1.00        15
#               Quercus cerris       1.00      1.00      1.00        14
#             Quercus coccinea       1.00      0.80      0.89        15
#              Quercus falcata       0.83      0.83      0.83         6
#           Quercus imbricaria       0.93      0.87      0.90        15
#           Quercus macrocarpa       1.00      1.00      1.00        18
#          Quercus marilandica       1.00      1.00      1.00        19
#            Quercus michauxii       0.95      1.00      0.97        18
#              Quercus montana       1.00      0.96      0.98        26
#        Quercus muehlenbergii       0.65      0.65      0.65        23
#                Quercus nigra       1.00      1.00      1.00        18
#            Quercus palustris       0.82      1.00      0.90        14
#              Quercus phellos       1.00      0.86      0.92        14
#                Quercus robur       1.00      1.00      1.00        15
#                Quercus rubra       1.00      0.88      0.93         8
#            Quercus shumardii       1.00      1.00      1.00        17
#             Quercus stellata       1.00      1.00      1.00        18
#             Quercus velutina       1.00      1.00      1.00        18
#           Quercus virginiana       1.00      0.94      0.97        17
#        Robinia pseudo-acacia       1.00      1.00      1.00        15
#             Salix babylonica       1.00      0.94      0.97        18
#            Salix caroliniana       0.95      1.00      0.97        18
#              Salix matsudana       1.00      1.00      1.00        17
#                  Salix nigra       0.91      1.00      0.95        21
#            Sassafras albidum       1.00      0.93      0.96        14
#           Staphylea trifolia       1.00      1.00      1.00        22
#     Stewartia pseudocamellia       0.94      1.00      0.97        17
#              Styrax japonica       0.96      1.00      0.98        24
#               Styrax obassia       1.00      0.89      0.94         9
#           Syringa reticulata       1.00      1.00      1.00        11
#           Taxodium distichum       0.95      1.00      0.97        18
#              Tilia americana       1.00      1.00      1.00        17
#                Tilia cordata       1.00      1.00      1.00        21
#               Tilia europaea       1.00      1.00      1.00        14
#              Tilia tomentosa       1.00      1.00      1.00        15
#               Toona sinensis       1.00      1.00      1.00         8
#             Tsuga canadensis       1.00      1.00      1.00        20
#              Ulmus americana       1.00      1.00      1.00        22
#                 Ulmus glabra       0.94      1.00      0.97        16
#             Ulmus parvifolia       1.00      1.00      1.00        17
#                Ulmus procera       1.00      0.92      0.96        12
#                 Ulmus pumila       0.96      1.00      0.98        27
#                  Ulmus rubra       1.00      1.00      1.00        33
#              Zelkova serrata       1.00      0.95      0.97        19
#
#                  avg / total       0.97      0.97      0.97      3240

# %%
# Plot confusion matrix
pylab.rcParams['figure.figsize'] = (30.0, 30.0)
cm = sklm.confusion_matrix(true_values, predictions[:,0], np.arange(len(listCat)))
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure()
plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')
plt.show()
